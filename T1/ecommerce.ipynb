# %%
import pandas as pd

columns = [
    'ProductID',
    'ProductName',
    'ProductBrand',
    'Gender',
    'Price (INR)',
    'NumImages',
    'Description',
    'PrimaryColor'
]

data = pd.read_csv('myntra_products_catalog.csv', header = None, names = columns)

# %%
data.head()
# Out:
#    ProductID                                        ProductName  ProductBrand  \
# 0  ProductID                                        ProductName  ProductBrand
# 1   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...          DKNY
# 2   10016283  EthnoVogue Women Beige & Grey Made to Measure ...    EthnoVogue
# 3   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...        SPYKAR
# 4   10015921  Raymond Men Blue Self-Design Single-Breasted B...       Raymond
#
#    Gender  Price (INR)  NumImages  \
# 0  Gender  Price (INR)  NumImages
# 1  Unisex        11745          7
# 2   Women         5810          7
# 3   Women          899          7
# 4     Men         5599          5
#
#                                          Description  PrimaryColor
# 0                                        Description  PrimaryColor
# 1  Black and grey printed medium trolley bag, sec...         Black
# 2  Beige & Grey made to measure kurta with churid...         Beige
# ...

# %%
data.drop(['ProductID'], axis=1, inplace=True)

# %%
data.head()
# Out:
#                                          ProductName  ProductBrand  Gender  \
# 0                                        ProductName  ProductBrand  Gender
# 1  DKNY Unisex Black & Grey Printed Medium Trolle...          DKNY  Unisex
# 2  EthnoVogue Women Beige & Grey Made to Measure ...    EthnoVogue   Women
# 3  SPYKAR Women Pink Alexa Super Skinny Fit High-...        SPYKAR   Women
# 4  Raymond Men Blue Self-Design Single-Breasted B...       Raymond     Men
#
#    Price (INR)  NumImages                                        Description  \
# 0  Price (INR)  NumImages                                        Description
# 1        11745          7  Black and grey printed medium trolley bag, sec...
# 2         5810          7  Beige & Grey made to measure kurta with churid...
# 3          899          7  Pink coloured wash 5-pocket high-rise cropped ...
# 4         5599          5  Blue self-design bandhgala suitBlue self-desig...
#
#    PrimaryColor
# 0  PrimaryColor
# 1         Black
# ...

# %%
main_fdata = []

columns.remove('ProductID')

for index, row in data.iterrows():
  fdata = {}
  for i in range(7):
    fdata[columns[i]] = row [columns[i]]
  main_fdata.append(fdata)

# %%
main_fdata
# Out:
# [{'ProductName': 'ProductName',
#   'ProductBrand': 'ProductBrand',
#   'Gender': 'Gender',
#   'Price (INR)': 'Price (INR)',
#   'NumImages': 'NumImages',
#   'Description': 'Description',
#   'PrimaryColor': 'PrimaryColor'},
#  {'ProductName': 'DKNY Unisex Black & Grey Printed Medium Trolley Bag',
#   'ProductBrand': 'DKNY',
#   'Gender': 'Unisex',
#   'Price (INR)': '11745',
#   'NumImages': '7',
#   'Description': 'Black and grey printed medium trolley bag, secured with a TSA lockOne handle on the top and one on the side, has a trolley with a retractable handle on the top and four corner mounted inline skate wheelsOne main zip compartment, zip lining, two compression straps with click clasps, one zip compartment on the flap with three zip pocketsWarranty: 5 yearsWarranty provided by Brand Owner / Manufacturer',
#   'PrimaryColor': ' Black'},
#  {'ProductName': 'EthnoVogue Women Beige & Grey Made to Measure Custom Made Kurta Set with Jacket',
#   'ProductBrand': 'EthnoVogue',
# ...
